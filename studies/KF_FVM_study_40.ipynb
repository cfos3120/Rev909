# %% [markdown]
# # Kolmogorov Flow Study

# %% [raw]
# <!-- Raw NBConvert cell (format: "html") --> <style> /* collapsed: show a slim bar; expanded: full content */ .code-collapsible {   position: relative;   overflow: hidden;   max-height: 2.2rem;               /* collapsed height (adjust) */   transition: max-height 0.25s ease;   margin-bottom: .5rem; } .code-collapsible.expanded {   max-height: 2000px;               /* large enough to expand */ } /* per-cell toggle button (inside the collapsible wrapper) */ .code-collapsible .cell-toggle {   position: absolute;   right: 6px;   top: 6px;   z-index: 10;   padding: 2px 6px;   border-radius: 4px;   border: 1px solid #bbb;   background: rgba(255,255,255,0.95);   font-size: 12px;   cursor: pointer; } /* global toggle button (fixed on page) */ #toggle-code-btn {   position: fixed;   top: 12px;   right: 12px;   z-index: 99999;   padding: 6px 10px;   border-radius: 6px;   border: 1px solid #bbb;   background: #f7f7f7;   cursor: pointer;   font-size: 13px; } </style> <div id="toggle-code-container">   <button id="toggle-code-btn" aria-pressed="false">Expand all code</button> </div> <script> (function () {   var collapsedByDefault = true; // change to false if you want code expanded by default   // helpers to detect common cell/output/markdown containers   function findCellAncestor(el){     var cur = el;     while(cur && cur !== document.body){       if (cur.classList && (cur.classList.contains('cell') || cur.classList.contains('jp-Cell') || /\bcell\b/.test(cur.className))) return cur;       cur = cur.parentElement;     }     return null;   }   function isInOutput(el, cell){     var cur = el;     while(cur && cur !== cell){       var cn = cur.className || '';       if (/\b(output|output_area|output_wrapper|jp-OutputArea|jp-Output)\b/.test(cn)) return true;       cur = cur.parentElement;     }     return false;   }   function isInMarkdown(el, cell){     var cur = el;     while(cur && cur !== cell){       var cn = cur.className || '';       if (/\b(text_cell|rendered_html|markdown|jp-MarkdownOutput|jp-RenderedHTMLCommon)\b/.test(cn)) return true;       cur = cur.parentElement;     }     return false;   }   // choose a sensible collapse target (prefer wrappers like .input_area or .highlight)   function findCollapseTarget(pre){     return pre.closest('.input_area, .highlight, .jp-InputArea, .cm-s, .CodeMirror') || pre;   }   // wrap an element into the collapsible wrapper and add per-cell toggle   function wrap(collTarget){     if (!collTarget || collTarget.dataset._collapsible) return null;     var wrapper = document.createElement('div');     wrapper.className = 'code-collapsible' + (collapsedByDefault ? '' : ' expanded');     var btn = document.createElement('button');     btn.className = 'cell-toggle';     btn.type = 'button';     btn.textContent = collapsedByDefault ? 'Show' : 'Hide';     btn.setAttribute('aria-expanded', collapsedByDefault ? 'false' : 'true');     btn.addEventListener('click', function(e){       e.stopPropagation();       var exp = wrapper.classList.toggle('expanded');       btn.textContent = exp ? 'Hide' : 'Show';       btn.setAttribute('aria-expanded', exp ? 'true' : 'false');       updateGlobalButton();     });     // move collTarget inside wrapper     collTarget.parentNode.insertBefore(wrapper, collTarget);     wrapper.appendChild(btn);     wrapper.appendChild(collTarget);     collTarget.dataset._collapsible = '1';     return wrapper;   }   // initialize: find code <pre> that are NOT outputs/markdown and wrap them   function init(){     var preList = Array.from(document.querySelectorAll('pre'));     var wrappers = [];     preList.forEach(function(pre){       var cell = findCellAncestor(pre);       if (!cell) return;       if (isInOutput(pre, cell)) return;     // skip outputs       if (isInMarkdown(pre, cell)) return;   // skip markdown-rendered blocks       var target = findCollapseTarget(pre);       if (!target) return;       var w = wrap(target);       if (w) wrappers.push(w);     });     // global button behavior     var globalBtn = document.getElementById('toggle-code-btn');     if (!globalBtn) return;     function anyExpanded(){ return wrappers.some(function(w){ return w.classList.contains('expanded'); }); }     function updateGlobalButton(){       var exp = anyExpanded();       globalBtn.textContent = exp ? 'Collapse all code' : 'Expand all code';       globalBtn.setAttribute('aria-pressed', exp ? 'true' : 'false');     }     globalBtn.addEventListener('click', function(){       var expand = !wrappers.every(function(w){ return w.classList.contains('expanded'); });       wrappers.forEach(function(w){         if (expand) w.classList.add('expanded'); else w.classList.remove('expanded');         var b = w.querySelector('.cell-toggle');         if (b) { b.textContent = expand ? 'Hide' : 'Show'; b.setAttribute('aria-expanded', expand ? 'true' : 'false'); }       });       updateGlobalButton();     });     updateGlobalButton();   }   if (document.readyState === 'loading') document.addEventListener('DOMContentLoaded', init); else init(); })(); </script>

# %%
import numpy as np
import torch 
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px
import pickle
import re

latex_textwidth_in_inches = 6.5  # change as needed
px_width = latex_textwidth_in_inches * 96
template = "simple_white"
font=dict(family="Times New Roman", size=11)
default_colors = px.colors.qualitative.T10
figure_path = r"C:\Users\Noahc\Documents\USYD\PHD\4 - Latex_new\00_figures\06_mno\kf"

# %%
import sys
sys.path.insert(0, r'C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909')
from utilities import PCA, w_to_u

# %%
# For 3D PCA scatter plots
pca_scene_dict = {'aspectmode':"manual", 
              'aspectratio':{'x':1,'y':1,'z':1.5},
              'xaxis':{'title':"1st PC"},
              'yaxis':{'title':"2nd PC"},
              'zaxis':{'title':"t"},}
pca_scene_camera = {'projection':{'type':"orthographic"},
                'up':{'x':0,'y':0,'z':1},
                'eye':{'x':0.5,'y':0.5,'z':0.5},
                'center':{'x':0.1,'y':0,'z':-0.1}
    }

# %% [markdown]
# ## $Re=40$

# %%
re40_path = r"C:\Users\Noahc\Documents\USYD\PHD\0 - Work Space\Markov Studies\2D_NS_Re40.npy"
dataset = np.load(re40_path)
print(f'Dataset has shape {dataset.shape}')
out_dim = 1
S = 64
dataset_reshape = dataset[:,100:,...].reshape(-1,S,S)

#max_norm = np.linalg.norm(dataset[:,100:,...], axis=(2, 3)).max()
max_norm = 270.7950466198188
# Out:
# Dataset has shape (200, 501, 64, 64)

# %% [markdown]
# models:

# %%
models = {'Dataset':{'data': torch.tensor(dataset_reshape)},
          'Spectral_H0':{'wandb_name': "classic-sweep-10"},
          'Spectral_H1':{'wandb_name': "different-sweep-11"},
          'Spectral_H2':{'wandb_name': "crimson-sweep-12"},
          'Spectral_H0_reg':{'wandb_name': "summer-sweep-1"},
          'Spectral_H1_reg':{'wandb_name': "volcanic-sweep-2"},
          'Spectral_H2_reg':{'wandb_name': "gallant-sweep-3"},
          'FDM_H0':{'wandb_name': "winter-sweep-16"},
          'FDM_H1':{'wandb_name': "dry-sweep-17"},
          'FDM_H2':{'wandb_name': "dark-sweep-18"},
          'FDM_H0_reg':{'wandb_name': "noble-sweep-7"},
          'FDM_H1_reg':{'wandb_name': "lucky-sweep-8"},
          'FDM_H2_reg':{'wandb_name': "breezy-sweep-9"},
          'FVM_H0':{'wandb_name': "peachy-sweep-13"},
          'FVM_H1':{'wandb_name': "crimson-sweep-14"},
          'FVM_H2':{'wandb_name': "toasty-sweep-15"},
          'FVM_H0_reg':{'wandb_name': "fast-sweep-4"},
          'FVM_H1_reg':{'wandb_name': "avid-sweep-5"},
          'FVM_H2_reg':{'wandb_name': "toasty-sweep-6"},
          }

sweep_path1 = r'C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR'
for key,__ in models.items():
    models[key]['name'] = re.sub(r"H([0-2])", r"H<sub>\1</sub>", key).replace("_"," ")

# %%
import os
from pathlib import Path
def fetch_results_path(models, level1_path=None, dictkey='wandb_name'):
    if level1_path is None:
        level1_path = os.getcwd()
        print(f'Searching for model exports in {level1_path}')
    level1_path = Path(level1_path)
    
    for key, value in models.items():
        if key == 'Dataset': continue
        run_path = None
        #wandb_name = value[dictkey].copy()

        for folder in level1_path.iterdir():
            if folder.is_dir() and folder.name.startswith(value[dictkey]):
                run_path = folder
                break
        
        if run_path is None:
            for level2_path in level1_path.iterdir():
                level2_path = Path(level2_path)
                if level2_path.is_dir():
                    for folder in level2_path.iterdir():
                        if folder.is_dir() and folder.name.startswith(value[dictkey]):
                            run_path = folder
                            break
        
        if run_path is None:
            print(f'{key} not found :(')
        else:
            models[key]['run_path'] = run_path
            print(f'{key} found at {run_path}')

# %% [markdown]
# fetch long rollout

# %%
solution_filename = 'long_rollout_10000.npy.npy'
fetch_results_path(models, level1_path=sweep_path1)
for key, value in models.items():
    try:
        models[key]['data'] = torch.tensor(np.load(f'{value["run_path"]}/{solution_filename}'))
        T = models[key]["data"].shape[0] # set T for total study
        print(f'{key} has solution size {models[key]["data"].shape}')
    except:
        print(f'{key} has no solution path')
# Out:
# Spectral_H0 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\classic-sweep-10-b7c0vm06
# Spectral_H1 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\different-sweep-11-fqnkg44t
# Spectral_H2 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\crimson-sweep-12-9v9jg1qs
# Spectral_H0_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\summer-sweep-1-swgstplh
# Spectral_H1_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\volcanic-sweep-2-6cxka8yc
# Spectral_H2_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\gallant-sweep-3-yhch2bfb
# FDM_H0 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\winter-sweep-16-ptku5y1g
# FDM_H1 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\dry-sweep-17-0dba7t06
# FDM_H2 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\dark-sweep-18-2ee46ki9
# FDM_H0_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\noble-sweep-7-wkd41b80
# FDM_H1_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\lucky-sweep-8-ght81ucn
# FDM_H2_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\breezy-sweep-9-fh0x0aew
# FVM_H0 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\peachy-sweep-13-t1garc5v
# FVM_H1 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\crimson-sweep-14-p9vfrkr3
# FVM_H2 found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\toasty-sweep-15-xsabp2j6
# FVM_H0_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\fast-sweep-4-47wm5wbv
# FVM_H1_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\avid-sweep-5-4vt40pfu
# FVM_H2_reg found at C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\results\ACFR\SWEEP-4i397axx\toasty-sweep-6-r5lvxi0u
# Dataset has no solution path
# Spectral_H0 has solution size torch.Size([10000, 64, 64, 1])
# Spectral_H1 has solution size torch.Size([10000, 64, 64, 1])
# Spectral_H2 has solution size torch.Size([10000, 64, 64, 1])
# Spectral_H0_reg has solution size torch.Size([10000, 64, 64, 1])
# Spectral_H1_reg has solution size torch.Size([10000, 64, 64, 1])
# Spectral_H2_reg has solution size torch.Size([10000, 64, 64, 1])
# FDM_H0 has solution size torch.Size([10000, 64, 64, 1])
# FDM_H1 has solution size torch.Size([10000, 64, 64, 1])
# FDM_H2 has solution size torch.Size([10000, 64, 64, 1])
# FDM_H0_reg has solution size torch.Size([10000, 64, 64, 1])
# FDM_H1_reg has solution size torch.Size([10000, 64, 64, 1])
# FDM_H2_reg has solution size torch.Size([10000, 64, 64, 1])
# FVM_H0 has solution size torch.Size([10000, 64, 64, 1])
# FVM_H1 has solution size torch.Size([10000, 64, 64, 1])
# FVM_H2 has solution size torch.Size([10000, 64, 64, 1])
# FVM_H0_reg has solution size torch.Size([10000, 64, 64, 1])
# FVM_H1_reg has solution size torch.Size([10000, 64, 64, 1])
# FVM_H2_reg has solution size torch.Size([10000, 64, 64, 1])

# %% [markdown]
# ### PCA Statistics

# %%
use_preloaded_encoding = True
save_new_encoding = False
encoding_folder = r'C:\Users\Noahc\Documents\USYD\PHD\8 - Github\Rev909\data'

PCA_dim = 50
if use_preloaded_encoding:
    with open(f"{encoding_folder}/x_pca_kf_re40.pkl", "rb") as f:
        x_pca = pickle.load(f)
else:
    x_pca = PCA(torch.tensor(dataset).reshape(-1, 64*64), PCA_dim, subtract_mean=False)
    if save_new_encoding:
        with open(f"{encoding_folder}/x_pca_kf_re40.pkl", "wb") as f:
            pickle.dump(x_pca, f)

# %%
#T = 10000
for key, value in models.items():
    models[key]['pca_encoding'] = x_pca.encode(value['data'].reshape(-1, 64*64))[:T]

# %%
fig_3d = go.Figure()
fig_2d = go.Figure()
n_T = 10000

show_model_list = ['Dataset', 'Spectral_H2', 'FDM_H2', 'FVM_H2']
for key, value in models.items():
    if key not in show_model_list: continue
    fig_3d.add_trace(go.Scatter3d(x=value['pca_encoding'][:n_T, 0], 
                               y=value['pca_encoding'][:n_T, 1], 
                               z=np.arange(n_T), 
                               name=value['name'], legendgroup=value['name'],
                               mode='markers', marker=dict(size=0.5)
                               ))
    fig_2d.add_trace(go.Scatter(x=value['pca_encoding'][:n_T, 0], 
                               y=value['pca_encoding'][:n_T, 1], 
                               #z=np.arange(n_T), 
                               name=value['name'], legendgroup=value['name'],
                               mode='markers', marker=dict(size=0.5)
                               ))
fig_3d.update_layout(
    font=font, template=template, plot_bgcolor='rgba(0,0,0,0)', showlegend=False,
    width=px_width/2, height = px_width/2, margin=dict(l=0, r=0, t=10, b=10),
    scene=pca_scene_dict, scene_camera=pca_scene_camera
)
fig_2d.update_layout(
    font=font, template=template, plot_bgcolor='rgba(0,0,0,0)', showlegend=True,
    width=px_width/2, height = px_width/2, margin=dict(l=10, r=10, t=10, b=10),
    xaxis={'title_text':"1st PC", 'title_standoff':1}, 
    yaxis={'title_text':"2nd PC", 'title_standoff':1},
    legend=dict(
        itemsizing="constant",   # keep legend markers same size as trace
        x=0.98, y=0.98,
        xanchor="right", yanchor="middle",
        orientation='h', tracegroupgap=0
    )
)
fig_3d.show(renderer="png")
fig_2d.show(renderer="png")

# %%
fig_3d.write_image(f"{figure_path}/MNO_KF40_PCA_3D.pdf")
fig_2d.write_image(f"{figure_path}/MNO_KF40_PCA_2D.pdf")

# %% [markdown]
# Now lets plot the dissipation regularizer:

# %% [raw]
# from dissipative_utils import sample_uniform_spherical_shell, linear_scale_dissipative_target
# x_diss = torch.tensor(sample_uniform_spherical_shell(T, [max_norm, max_norm*4], (S, S, out_dim)), dtype=torch.float)
# y_diss = linear_scale_dissipative_target(x_diss, 0.5)
#
# diss_pca = PCA(x_diss.reshape(-1, 64*64), PCA_dim, subtract_mean=False)
# x_diss_pca = diss_pca.encode(x_diss.reshape(-1, 64*64))[:T]
# y_diss_pca = diss_pca.encode(y_diss.reshape(-1, 64*64))[:T]

# %% [raw]
# fig_2d = go.Figure()
# n_T = 10000
#
# fig_2d.add_trace(go.Scatter(x=models['Dataset']['pca_encoding'][:n_T, 0],
#                             y=models['Dataset']['pca_encoding'][:n_T, 1],
#                             #z=np.arange(n_T),
#                             name=models['Dataset']['name'], legendgroup=models['Dataset']['name'],
#                             mode='markers', marker=dict(size=0.5, color='blue')
#                             ))
# fig_2d.add_trace(go.Scatter(x=x_diss_pca[:n_T, 0],
#                             y=x_diss_pca[:n_T, 1],
#                             #z=np.arange(n_T),
#                             name=models['Dataset']['name'], legendgroup=models['Dataset']['name'],
#                             mode='markers', marker=dict(size=0.5, color='red')
#                             ))
# fig_2d.add_trace(go.Scatter(x=y_diss_pca[:n_T, 0],
#                             y=y_diss_pca[:n_T, 1],
#                             #z=np.arange(n_T),
#                             name=models['Dataset']['name'], legendgroup=models['Dataset']['name'],
#                             mode='markers', marker=dict(size=0.5, color='green')
#                             ))
# fig_2d.update_layout(
#     font=font, template=template, plot_bgcolor='rgba(0,0,0,0)', showlegend=False,
#     width=px_width/2, height = px_width/2, margin=dict(l=10, r=10, t=10, b=10),
#     xaxis={'title_text':"1st PC", 'title_standoff':1},
#     yaxis={'title_text':"2nd PC", 'title_standoff':1}
#     #scene=pca_scene_dict, scene_camera=pca_scene_camera
# )
# fig_2d.show(renderer="png")

# %% [markdown]
# ### Vorticity distribution

# %%
from scipy.stats import gaussian_kde
n_bins = 50
for key, value in models.items():
    kde_data = gaussian_kde(value['data'].reshape(-1)[np.random.permutation(len(value['data'].reshape(-1)))[:T]],
                            bw_method='scott')
    bins_data = np.linspace(value['data'].reshape(-1).min(), value['data'].reshape(-1).max(), n_bins)
    bins_data = np.linspace(-3, 3, n_bins)
    models[key]['vorticity_dist'] = kde_data.evaluate(bins_data)
    models[key]['vorticity_bins'] = bins_data

# %%
fig = go.Figure()
type = 'Spectral'
show_model_list = ['Dataset', f'{type}_H0_reg', f'{type}_H1_reg', f'{type}_H2_reg']
colors = ['Black', default_colors[0], default_colors[1], default_colors[2]]
names = ['Dataset', 'H<sub>0</sub>', 'H<sub>1</sub>', 'H<sub>2</sub>']
#i = 0
#for __, (key, value) in enumerate(models.items()):
    #if key not in show_model_list: continue
for i, key in enumerate(show_model_list):
    fig.add_trace(go.Scatter(x=models[key]['vorticity_bins'],
                             y=models[key]['vorticity_dist'],
                             name=names[i], legendgroup=names[i],
                             mode='lines', line=dict(width=1, color=colors[i])
                             ))
    #i+=1
fig.update_layout(
    font=font, template=template, plot_bgcolor='rgba(0,0,0,0)', showlegend=True if type == 'Spectral' else False,
    width=px_width/2, height = px_width/2, margin=dict(l=10, r=10, t=10, b=10),
    xaxis={'title_text':"Vorticity", 'title_standoff':1, 'showgrid':True, 
           'range':[models['Dataset']['vorticity_bins'].min(), models['Dataset']['vorticity_bins'].max()]}, 
    yaxis={'title_text':"Density", 'title_standoff':1, 'showgrid':True,
           'range':[models['Dataset']['vorticity_dist'].min(), models['Dataset']['vorticity_dist'].max()*1.2]},
    legend=dict(
        #itemsizing="constant",   # keep legend markers same size as trace
        x=1, y=1,
        xanchor="right", yanchor="top",
        orientation='v', tracegroupgap=0,
        bgcolor="rgba(255,255,255,1)",
        bordercolor="black",
        borderwidth=1
    )
)
fig.show(renderer="png")

fig.write_image(f"{figure_path}/MNO_KF40_vorticity_{type}.pdf")

# %%
f"{figure_path}/MNO_KF40_vorticity_{type}.pdf"
# Out:
# 'C:\\Users\\Noahc\\Documents\\USYD\\PHD\\4 - Latex_new\\00_figures\\06_mno\\kf/MNO_KF40_vorticity_Spectral.pdf'

# %% [markdown]
# ### Energy Spectrum

# %%
def spectrum2(u, s):
    T = u.shape[0]
    u = u.reshape(T, s, s)
    u = torch.fft.fft2(u)

    # 2d wavenumbers following Pytorch fft convention
    k_max = s // 2
    wavenumers = torch.cat((torch.arange(start=0, end=k_max, step=1), \
                            torch.arange(start=-k_max, end=0, step=1)), 0).repeat(s, 1)
    k_x = wavenumers.transpose(0, 1)
    k_y = wavenumers
    
    # Sum wavenumbers
    sum_k = torch.abs(k_x) + torch.abs(k_y)
    sum_k = sum_k.numpy()
    
    # Remove symmetric components from wavenumbers
    index = -1.0 * np.ones((s, s))
    index[0:k_max + 1, 0:k_max + 1] = sum_k[0:k_max + 1, 0:k_max + 1]

    spectrum = np.zeros((T, s))
    for j in range(1, s + 1):
        ind = np.where(index == j)
        spectrum[:, j - 1] = np.sqrt( (u[:, ind[0], ind[1]].sum(axis=1)).abs() ** 2)
        
    spectrum = spectrum.mean(axis=0)
    return spectrum

# %%
for key, value in models.items():
    models[key]['spectrum'] = spectrum2(value['data'][:1000,...].reshape(-1,S,S), S)[:S//2]

# %%
fig = go.Figure()

type = 'Spectral'
show_model_list = ['Dataset', f'{type}_H0_reg', f'{type}_H1_reg', f'{type}_H2_reg']
colors = ['Black', default_colors[0], default_colors[1], default_colors[2]]
names = ['Dataset', 'H<sub>0</sub>', 'H<sub>1</sub>', 'H<sub>2</sub>']

for i, key in enumerate(show_model_list):
    fig.add_trace(go.Scatter(y=models[key]['spectrum'],
                             name=names[i], legendgroup=names[i],
                             mode='lines', line=dict(width=1, color=colors[i])
                             ))
fig.update_layout(
    font=font, template=template, plot_bgcolor='rgba(0,0,0,0)', showlegend=True if type == 'Spectral' else False,
    width=px_width/2, height = px_width/2, margin=dict(l=10, r=10, t=10, b=10),
    xaxis={'title_text':"Wavenumber", 'title_standoff':1, 'showgrid':False}, 
    yaxis={'title_text':"Energy", 'title_standoff':1, 'type':"log", 'showgrid':True},
    legend=dict(
        #itemsizing="constant",   # keep legend markers same size as trace
        x=0.98, y=0.98,
        xanchor="right", yanchor="top",
        orientation='v', tracegroupgap=0,
        bgcolor="rgba(255,255,255,1)",
        bordercolor="black",
        borderwidth=1
    )
)
fig.show()

fig.write_image(f"{figure_path}/MNO_KF40_KE_{type}.pdf")

# %% [markdown]
# ### Rollout Visualization

# %%
for key, value in models.items():

# %%
B, T, S, _ = dataset.shape
ntrain = int(0.9*B)
ntest = B - ntrain
rollout_idx = -ntest+1

# %%
models.keys()
# Out:
# dict_keys(['Dataset', 'Spectral_H0', 'Spectral_H1', 'Spectral_H2', 'Spectral_H0_reg', 'Spectral_H1_reg', 'Spectral_H2_reg', 'FDM_H0', 'FDM_H1', 'FDM_H2', 'FDM_H0_reg', 'FDM_H1_reg', 'FDM_H2_reg', 'FVM_H0', 'FVM_H1', 'FVM_H2', 'FVM_H0_reg', 'FVM_H1_reg', 'FVM_H2_reg'])

# %%
models['Spectral_H0']['data'].shape
# Out:
# torch.Size([10000, 64, 64, 1])

# %%
models[f'{type}_H2']['data'].shape
# Out:
# torch.Size([10000, 64, 64, 1])

# %%
import plotly.subplots as subplots
rows=4
cols=5
fig = subplots.make_subplots(rows,cols,vertical_spacing=0.01,horizontal_spacing=0.01, 
                             #row_titles=['Dataset', 'Spectral', 'FDM', 'FVM'],
                             column_titles=['t = 100', 't = 200', 't = 300', 't = 400', 't = 500'])
#fig.add_trace(go.Heatmap(z=du_fvm['dwdx'][0,...,0], showscale=False),1,1)

for i, type in enumerate(['Dataset', 'Spectral', 'FDM', 'FVM']):
    for j, time_step in enumerate([100,200,300,400,500]):
        if type == 'Dataset':
            data = dataset[rollout_idx,100:,...]
        else:
            data = models[f'{type}_H2_reg']['data'][...,0]

        fig.add_trace(go.Heatmap(z=data[time_step-100,...], showscale=False, coloraxis='coloraxis1'),i+1,j+1)


#fig.add_trace(go.Heatmap(z=first_soblev[0,...,0].real, showscale=False),1,3)
for i in range(1, rows*cols + 1):
    fig.update_xaxes(scaleanchor=f"y{i}", ticks='', scaleratio=1, linecolor='rgba(0,0,0,0)', showgrid=False, showticklabels=False, row=(i-1)//cols + 1, col=(i-1)%cols + 1)
    fig.update_yaxes(constrain='domain', ticks='', linecolor='rgba(0,0,0,0)', showgrid=False, showticklabels=False, row=(i-1)//cols + 1, col=(i-1)%cols + 1)
fig.update_layout(
    font=dict(family="Times New Roman", size=11), template = "simple_white",
    #xaxis=dict(showticklabels=True, showgrid=True, zeroline=False, linecolor='rgba(0,0,0,0)', title='Angle', scaleanchor='y', scaleratio=1.5, title_standoff=0),
    #yaxis=dict(showticklabels=True, showgrid=True, zeroline=False, linecolor='rgba(0,0,0,0)', title='Radius'),
    #plot_bgcolor='rgba(0,0,0,0)',    # Background color inside the plot area
    width=px_width*1, showlegend=False, margin=dict(l=60, r=10, t=20, b=10), height = px_width*0.8, 
    coloraxis1=dict(colorscale='IceFire', showscale=False),
)
# for ann in fig['layout']['annotations']:
#     ann['y'] -= 0.03  # reduce y offset (smaller -> closer)
for i, t in enumerate(['Dataset', 'Spectral', 'FDM', 'FVM']):
    fig.add_annotation(
        text=t,
        x=-0.06,           # slightly left of the axis
        y=S/2,    # evenly spaced from bottom (0) to top (1)
        xref='paper',xanchor='center',
        yref=f'y{cols*i+1}',
        showarrow=False,
        textangle=0,
        font=dict(size=14)
    )

# for i in range(len(fig.layout.annotations)):
#    fig.layout.annotations[i].y = 0.93  # Adjust y coordinate closer to plot
fig.show()
fig.write_image(f"{figure_path}/MNO_KF40_rollout_timesteps.pdf")
